# %%
import pandas as pd

# %% [markdown]
# ## Ingestion

# %%
df= pd.read_csv('data.csv')

# %%
df
# Out:
#       id cell_nuclei_type dataset_name           tasks       models
# 0      0       Epithelial      MoNuSAC    Segmentation    Hover-Net
# 1      1       Lymphocyte      MoNuSAC    Segmentation    Hover-Net
# 2      2       Macrophage      MoNuSAC    Segmentation    Hover-Net
# 3      3       Neutrophil      MoNuSAC    Segmentation    Hover-Net
# 4      4       Epithelial      PanNuke  Classification       ResNet
# ..   ...              ...          ...             ...          ...
# 332  332      Plasma Cell         LUNG    Segmentation     DenseNet
# 333  333       Fibroblast   Camelyon16  Classification  MobileNetV3
# 334  334       Lymphocyte      PanNuke    Segmentation          FPN
# 335  335       Macrophage   Camelyon17  Classification    ResNet101
# 336  336       Neutrophil         TNBC       Detection       YOLOv3
#
# [337 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['id', 'cell_nuclei_type', 'dataset_name', 'tasks', 'models'], dtype='object')

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/minsearch/main/minsearch.py
# Out:
# --2024-09-04 21:00:54--  https://raw.githubusercontent.com/alexeygrigorev/minsearch/main/minsearch.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3832 (3.7K) [text/plain]
# Saving to: ‘minsearch.py.2’
#
# minsearch.py.2      100%[===================>]   3.74K  --.-KB/s    in 0s
#
# 2024-09-04 21:00:55 (26.5 MB/s) - ‘minsearch.py.2’ saved [3832/3832]

# %%
documents=df.to_dict(orient='records')

# %%
documents
# Out:
# [{'id': 0,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Hover-Net'},
#  {'id': 1,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Hover-Net'},
#  {'id': 2,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Hover-Net'},
#  {'id': 3,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Hover-Net'},
#  {'id': 4,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 5,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 6,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 7,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 8,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'Mask R-CNN'},
#  {'id': 9,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 10,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 11,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'U-Net'},
#  {'id': 12,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation and Classification',
#   'models': 'Hover-Net'},
#  {'id': 13,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'Mask R-CNN'},
#  {'id': 14,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'ResNet'},
#  {'id': 15,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'DeepLab'},
#  {'id': 16,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'Inception-V3'},
#  {'id': 17,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'U-Net'},
#  {'id': 18,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 19,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation and Classification',
#   'models': 'Hover-Net'},
#  {'id': 20,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'Mask R-CNN'},
#  {'id': 21,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 22,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 23,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'U-Net'},
#  {'id': 24,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'ResNet'},
#  {'id': 25,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation and Classification',
#   'models': 'Hover-Net'},
#  {'id': 26,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 27,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'Mask R-CNN'},
#  {'id': 28,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 29,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 30,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'U-Net'},
#  {'id': 31,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'ResNet'},
#  {'id': 32,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Hover-Net'},
#  {'id': 33,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Mask R-CNN'},
#  {'id': 34,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'DeepLab'},
#  {'id': 35,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'Inception-V3'},
#  {'id': 36,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'U-Net'},
#  {'id': 37,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation and Classification',
#   'models': 'ResNet'},
#  {'id': 38,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'Hover-Net'},
#  {'id': 39,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 40,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'Mask R-CNN'},
#  {'id': 41,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'Hover-Net'},
#  {'id': 42,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'DeepLab'},
#  {'id': 43,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Inception-V3'},
#  {'id': 44,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'U-Net'},
#  {'id': 45,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'ResNet'},
#  {'id': 46,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation and Classification',
#   'models': 'Hover-Net'},
#  {'id': 47,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Mask R-CNN'},
#  {'id': 48,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 49,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 50,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'U-Net'},
#  {'id': 51,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'ResNet'},
#  {'id': 52,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'Hover-Net'},
#  {'id': 53,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation and Classification',
#   'models': 'Mask R-CNN'},
#  {'id': 54,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'DeepLab'},
#  {'id': 55,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'Inception-V3'},
#  {'id': 56,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'U-Net'},
#  {'id': 57,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'ResNet'},
#  {'id': 58,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation and Classification',
#   'models': 'Hover-Net'},
#  {'id': 59,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Mask R-CNN'},
#  {'id': 60,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 61,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'U-Net'},
#  {'id': 62,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'ResNet'},
#  {'id': 63,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Hover-Net'},
#  {'id': 64,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'Mask R-CNN'},
#  {'id': 65,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation and Classification',
#   'models': 'DeepLab'},
#  {'id': 66,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'Inception-V3'},
#  {'id': 67,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'U-Net'},
#  {'id': 68,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'ResNet'},
#  {'id': 69,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'Hover-Net'},
#  {'id': 70,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'Mask R-CNN'},
#  {'id': 71,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'DeepLab'},
#  {'id': 72,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 73,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'U-Net'},
#  {'id': 74,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation and Classification',
#   'models': 'ResNet'},
#  {'id': 75,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'Hover-Net'},
#  {'id': 76,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'Mask R-CNN'},
#  {'id': 77,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'DeepLab'},
#  {'id': 78,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'Inception-V3'},
#  {'id': 79,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'U-Net'},
#  {'id': 80,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 81,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'Mask R-CNN'},
#  {'id': 82,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation and Classification',
#   'models': 'DeepLab'},
#  {'id': 83,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'Inception-V3'},
#  {'id': 84,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'ResNet'},
#  {'id': 85,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'Hover-Net'},
#  {'id': 86,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Mask R-CNN'},
#  {'id': 87,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'DeepLab'},
#  {'id': 88,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'Inception-V3'},
#  {'id': 89,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'U-Net'},
#  {'id': 90,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'Inception-ResNet'},
#  {'id': 91,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'EfficientNet'},
#  {'id': 92,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 93,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 94,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 95,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 96,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 97,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 98,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'VGG16'},
#  {'id': 99,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 100,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 101,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'LinkNet'},
#  {'id': 102,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 103,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'MobileNetV2'},
#  {'id': 104,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 105,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'Dual Path Network'},
#  {'id': 106,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B3'},
#  {'id': 107,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'RefineNet'},
#  {'id': 108,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'DenseUNet'},
#  {'id': 109,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 110,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 111,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'PSPNet'},
#  {'id': 112,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'FPN'},
#  {'id': 113,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'ResNeXt'},
#  {'id': 114,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 115,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'UNet3+'},
#  {'id': 116,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'Inception-V4'},
#  {'id': 117,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 118,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'Attn-UNet'},
#  {'id': 119,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 120,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'MobileNet'},
#  {'id': 121,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 122,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 123,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'VGG19'},
#  {'id': 124,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 125,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 126,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 127,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'ResNet50'},
#  {'id': 128,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 129,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 130,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B1'},
#  {'id': 131,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 132,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 133,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 134,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 135,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'RefineNet'},
#  {'id': 136,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 137,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 138,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 139,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 140,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'EfficientNet'},
#  {'id': 141,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'UNet3+'},
#  {'id': 142,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 143,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 144,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 145,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 146,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 147,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 148,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 149,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'ResNet101'},
#  {'id': 150,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 151,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 152,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'VGG16'},
#  {'id': 153,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 154,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 155,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'Inception-ResNet'},
#  {'id': 156,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 157,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'UNet3+'},
#  {'id': 158,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'EfficientNet'},
#  {'id': 159,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 160,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 161,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 162,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 163,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 164,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 165,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'UNet++'},
#  {'id': 166,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 167,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 168,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'RetinaNet'},
#  {'id': 169,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 170,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'DenseUNet'},
#  {'id': 171,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet50'},
#  {'id': 172,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 173,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'PSPNet'},
#  {'id': 174,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B0'},
#  {'id': 175,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 176,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 177,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 178,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 179,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'UNet3+'},
#  {'id': 180,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 181,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 182,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Inception-V4'},
#  {'id': 183,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 184,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'EfficientNet-B1'},
#  {'id': 185,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'ResNeXt'},
#  {'id': 186,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 187,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 188,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'VGG19'},
#  {'id': 189,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 190,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'PSPNet'},
#  {'id': 191,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 192,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 193,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'Inception-ResNet'},
#  {'id': 194,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 195,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNet101'},
#  {'id': 196,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 197,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 198,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 199,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 200,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 201,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 202,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B2'},
#  {'id': 203,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 204,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 205,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 206,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 207,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 208,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'ResNeXt'},
#  {'id': 209,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 210,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'EfficientNet'},
#  {'id': 211,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 212,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 213,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'DenseUNet'},
#  {'id': 214,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 215,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 216,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 217,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 218,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B3'},
#  {'id': 219,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 220,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 221,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'MobileNet'},
#  {'id': 222,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 223,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'ResNet101'},
#  {'id': 224,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 225,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 226,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B0'},
#  {'id': 227,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 228,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'DenseUNet'},
#  {'id': 229,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 230,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'Inception-V4'},
#  {'id': 231,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 232,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 233,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 234,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 235,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 236,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 237,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 238,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 239,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 240,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 241,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 242,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 243,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 244,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 245,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B1'},
#  {'id': 246,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 247,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 248,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 249,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 250,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 251,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'MobileNet'},
#  {'id': 252,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 253,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 254,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 255,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 256,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'UNet3+'},
#  {'id': 257,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'Inception-ResNet'},
#  {'id': 258,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 259,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'EfficientNet'},
#  {'id': 260,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 261,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B0'},
#  {'id': 262,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'ResNeXt'},
#  {'id': 263,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 264,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 265,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 266,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 267,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 268,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 269,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 270,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 271,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B2'},
#  {'id': 272,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 273,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Classification',
#   'models': 'Inception-V4'},
#  {'id': 274,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 275,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 276,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Xception'},
#  {'id': 277,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 278,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'ResNet50'},
#  {'id': 279,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'EfficientNet'},
#  {'id': 280,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'MobileNet'},
#  {'id': 281,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 282,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 283,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'UNet3+'},
#  {'id': 284,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 285,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 286,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 287,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 288,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'DenseUNet'},
#  {'id': 289,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 290,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 291,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 292,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 293,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B1'},
#  {'id': 294,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 295,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'ResNet101'},
#  {'id': 296,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 297,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 298,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 299,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 300,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Inception-ResNet'},
#  {'id': 301,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 302,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'EfficientNet'},
#  {'id': 303,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 304,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Detection',
#   'models': 'SSD'},
#  {'id': 305,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 306,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'DenseUNet'},
#  {'id': 307,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B2'},
#  {'id': 308,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 309,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 310,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 311,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 312,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Classification',
#   'models': 'NASNet'},
#  {'id': 313,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 314,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 315,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 316,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'DenseNet'},
#  {'id': 317,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 318,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'EfficientNet'},
#  {'id': 319,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'MobileNet'},
#  {'id': 320,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'UNet++'},
#  {'id': 321,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Inception-V4'},
#  {'id': 322,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 323,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'EfficientNet-B0'},
#  {'id': 324,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'DenseUNet'},
#  {'id': 325,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'Faster R-CNN'},
#  {'id': 326,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 327,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Classification',
#   'models': 'Inception-ResNet'},
#  {'id': 328,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Segmentation',
#   'models': 'HRNet'},
#  {'id': 329,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'RetinaNet'},
#  {'id': 330,
#   'cell_nuclei_type': 'Epithelial',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'DeepLabV3+'},
#  {'id': 331,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 332,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'LUNG',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'},
#  {'id': 333,
#   'cell_nuclei_type': 'Fibroblast',
#   'dataset_name': 'Camelyon16',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 334,
#   'cell_nuclei_type': 'Lymphocyte',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'FPN'},
#  {'id': 335,
#   'cell_nuclei_type': 'Macrophage',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Classification',
#   'models': 'ResNet101'},
#  {'id': 336,
#   'cell_nuclei_type': 'Neutrophil',
#   'dataset_name': 'TNBC',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'}]

# %%
import minsearch

# %%
index = minsearch.Index(
    text_fields=['cell_nuclei_type', 'dataset_name', 'tasks', 'models'],
    keyword_fields=["id"]
)

# %%
index.fit(documents)

# %% [markdown]
# ## RAG Flow

# %%
from openai import OpenAI
client = OpenAI()

# %%
query="give me datasets most suitable for Plasma Cell"

# %%
index.search(query)
# Out:
# [{'id': 43,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Segmentation',
#   'models': 'Inception-V3'},
#  {'id': 32,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'MoNuSAC',
#   'tasks': 'Classification',
#   'models': 'Hover-Net'},
#  {'id': 268,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'MobileNetV3'},
#  {'id': 281,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Detection',
#   'models': 'YOLOv5'},
#  {'id': 49,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Classification',
#   'models': 'Inception-V3'},
#  {'id': 277,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv4'},
#  {'id': 118,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'TNBC',
#   'tasks': 'Segmentation',
#   'models': 'Attn-UNet'},
#  {'id': 198,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'Camelyon17',
#   'tasks': 'Detection',
#   'models': 'YOLOv3'},
#  {'id': 55,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'PanNuke',
#   'tasks': 'Segmentation',
#   'models': 'Inception-V3'},
#  {'id': 153,
#   'cell_nuclei_type': 'Plasma Cell',
#   'dataset_name': 'CoNSeP',
#   'tasks': 'Segmentation',
#   'models': 'DenseNet'}]

# %%
import os

# %%
os.environ['OPENAI_API_KEY']='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'

# %%
def search(query):
    boost = {}
    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
documents[0]
# Out:
# {'id': 0,
#  'cell_nuclei_type': 'Epithelial',
#  'dataset_name': 'MoNuSAC',
#  'tasks': 'Segmentation',
#  'models': 'Hover-Net'}

# %%
prompt_template = """
You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT:
{context}
""".strip()

entry_template = """
cell_nuclei_type: {cell_nuclei_type}
dataset_name: {dataset_name}
tasks: {tasks}
models: {models}
""".strip()

def build_prompt(query, search_results):
   

    context = ""
    
    for doc in search_results:
        context = context + entry_template.format(**doc) + "\n\n"
    
    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
search_results=search(query)
prompt=build_prompt(query,search_results)

# %%
print(prompt)
# Out:
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: give me datasets most suitable for Plasma Cell
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet

# %%
def llm(prompt, model='gpt-4o-mini'):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
def rag(query, model='gpt-4o-mini'):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    #print(prompt)
    answer = llm(prompt, model=model)
    return answer

# %%
question='What are the segmentation tasks available for the Epithelial cell nuclei type?'
answer=rag(question)
print(answer)
# Out:
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the segmentation tasks available for the Epithelial cell nuclei type?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net
# The available segmentation tasks for the Epithelial cell nuclei type include:
#
# 1. LUNG dataset - Segmentation using:
#    - DeepLabV3+
#    - ResNet
#    - UNet++
#    - FPN
#
# 2. MoNuSAC dataset - Segmentation using:
#    - DenseUNet
#    - Hover-Net
#
# 3. CoNSeP dataset - Segmentation using:
#    - HRNet
#    - DeepLab
#
# 4. PanNuke dataset - Segmentation using:
#    - HRNet
#
# 5. TNBC dataset - Segmentation using:
#    - ResNet

# %% [markdown]
# ## Retrieval Evaluation

# %%
df_question=pd.read_csv('data/ground_truth.csv')

# %%
df_question
# Out:
#        id                                           question
# 0       0  What are the segmentation tasks available for ...
# 1       0  Can you provide details about the MoNuSAC data...
# 2       0  Which specific model, such as Hover-Net, is be...
# 3       0  What are the performance metrics for the Hover...
# 4       1  What is the best model for segmenting lymphocy...
# ...   ...                                                ...
# 1031  257  What are the characteristics of the LUNG datas...
# 1032  258  What is the best model for detecting plasma ce...
# 1033  258  Which datasets are available for the detection...
# 1034  258  How does YOLOv3 perform in the task of plasma ...
# 1035  258  Can you provide details on the tasks associate...
#
# [1036 rows x 2 columns]

# %%
ground_truth=df_question.to_dict(orient='records')

# %%
ground_truth[0]
# Out:
# {'id': 0,
#  'question': 'What are the segmentation tasks available for the Epithelial cell nuclei type?'}

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)
def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
def minsearch_search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
def evaluate(ground_truth, search_function):
 relevance_total = []

 for q in tqdm(ground_truth):
     doc_id = q['id']
     results = search_function(q)

     # Check for relevance
     relevance = [d['id'] == doc_id for d in results]
     relevance_total.append(relevance)

 return {
     'hit_rate': hit_rate(relevance_total),
     'mrr': mrr(relevance_total),
 }

# %%
from tqdm.auto import tqdm

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['question']))
# Out:
#   0%|          | 0/1036 [00:00<?, ?it/s]
# {'hit_rate': 0.8861003861003861, 'mrr': 0.5347892535392536}

# %%
from tqdm import tqdm

def evaluate(ground_truth, search_function):
    relevance_total = []
    no_results_queries = []
    low_rank_queries = []

    for q in tqdm(ground_truth):
        doc_id = q['id']
        results = search_function(q['question'])
        
        if not results:
            print(f"No results found for query ID: {doc_id}")
            no_results_queries.append(q)
            continue
        
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)
        
        if True in relevance and relevance.index(True) > 9:  # If correct result is not in top 10
            low_rank_queries.append((q, relevance.index(True)))

    hit_rate_value = hit_rate(relevance_total)
    mrr_value = mrr(relevance_total)

    print(f"Queries with no results: {len(no_results_queries)}")
    print(f"Queries with low-ranked correct results: {len(low_rank_queries)}")
    
    return {
        'hit_rate': hit_rate_value,
        'mrr': mrr_value,
        'no_results_queries': no_results_queries,
        'low_rank_queries': low_rank_queries
    }

# Usage
results = evaluate(ground_truth, lambda q: minsearch_search(q))
print(f"Hit Rate: {results['hit_rate']:.4f}")
print(f"MRR: {results['mrr']:.4f}")

# Analysis of problematic queries
print("\nSample of queries with no results:")
for q in results['no_results_queries'][:5]:  # Print first 5
    print(f"ID: {q['id']}, Question: {q['question']}")

print("\nSample of queries with low-ranked correct results:")
for q, rank in results['low_rank_queries'][:5]:  # Print first 5
    print(f"ID: {q['id']}, Rank: {rank}, Question: {q['question']}")
# Out:
#  37%|████████████████████████████████████████                                                                     | 381/1036 [00:00<00:00, 977.94it/s]
# No results found for query ID: 54
#  76%|█████████████████████████████████████████████████████████████████████████████████▋                          | 784/1036 [00:00<00:00, 1000.28it/s]
# No results found for query ID: 164
# No results found for query ID: 191
# No results found for query ID: 200
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1036/1036 [00:01<00:00, 981.89it/s]
# Queries with no results: 4
# Queries with low-ranked correct results: 0
# Hit Rate: 0.8895
# MRR: 0.5369
#
# Sample of queries with no results:
# ID: 54, Question: What is the best model for detecting Neutrophils in histopathology analysis?
# ID: 164, Question: Can you provide information on the available datasets specifically for detecting Neutrophils in histopathology?
# ID: 191, Question: Can you provide the available datasets for the task of detecting neutrophils?
# ID: 200, Question: Can you provide details on the tasks associated with detecting lymphocytes in histopathology datasets?
#
# Sample of queries with low-ranked correct results:

# %%
import numpy as np
from typing import List, Dict, Any

def precision_at_k(relevance: List[bool], k: int) -> float:
    """
    Calculate Precision@k
    
    Args:
    relevance (List[bool]): List of boolean values indicating relevance of each result
    k (int): The 'k' in Precision@k
    
    Returns:
    float: Precision@k score
    """
    if len(relevance) < k:
        return sum(relevance) / len(relevance)
    return sum(relevance[:k]) / k

def average_precision(relevance: List[bool]) -> float:
    """
    Calculate Average Precision
    
    Args:
    relevance (List[bool]): List of boolean values indicating relevance of each result
    
    Returns:
    float: Average Precision score
    """
    if not any(relevance):
        return 0.0
    score = 0.0
    num_relevant = 0
    for i, rel in enumerate(relevance, 1):
        if rel:
            num_relevant += 1
            score += num_relevant / i
    return score / num_relevant

def ndcg(relevance: List[bool], k: int = None) -> float:
    """
    Calculate Normalized Discounted Cumulative Gain
    
    Args:
    relevance (List[bool]): List of boolean values indicating relevance of each result
    k (int, optional): The 'k' in NDCG@k. If None, use full list.
    
    Returns:
    float: NDCG score
    """
    if k is None:
        k = len(relevance)
    
    dcg = sum((rel / np.log2(i + 2) for i, rel in enumerate(relevance[:k])))
    idcg = sum((1 / np.log2(i + 2) for i in range(min(sum(relevance), k))))
    
    return dcg / idcg if idcg > 0 else 0.0

def evaluate_search(ground_truth: List[Dict[str, Any]], search_function: callable) -> Dict[str, float]:
    relevance_total = []
    for i, q in enumerate(ground_truth):
        doc_id = q['id']
        results = search_function(q)
        if not results:
            print(f"No results found for query ID: {doc_id}")
            continue
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)
        if i < 5:  # Print details for the first 5 queries
            print(f"Query {i+1}:")
            print(f"  Document ID: {doc_id}")
            print(f"  Relevance list: {relevance[:10]}")  # First 10 results
            print(f"  Precision@1: {precision_at_k(relevance, 1)}")
            print(f"  Precision@5: {precision_at_k(relevance, 5)}")
            print(f"  NDCG@5: {ndcg(relevance, 5)}")
            print()
    
    hit_rate_value = hit_rate(relevance_total)
    mrr_value = mrr(relevance_total)
    
    metrics = {
        'hit_rate': hit_rate_value,
        'mrr': mrr_value,
        'precision@1': np.mean([precision_at_k(rel, 1) for rel in relevance_total]),
        'precision@5': np.mean([precision_at_k(rel, 5) for rel in relevance_total]),
        'precision@10': np.mean([precision_at_k(rel, 10) for rel in relevance_total]),
        'map': np.mean([average_precision(rel) for rel in relevance_total]),
        'ndcg@5': np.mean([ndcg(rel, 5) for rel in relevance_total]),
        'ndcg@10': np.mean([ndcg(rel, 10) for rel in relevance_total]),
    }
    
    return metrics

# Example usage
results = evaluate_search(ground_truth, lambda q: minsearch_search(q['question']))
print(results)
# Out:
# Query 1:
#   Document ID: 0
#   Relevance list: [False, False, False, False, False, False, False, False, False, True]
#   Precision@1: 0.0
#   Precision@5: 0.0
#   NDCG@5: 0.0
#
# Query 2:
#   Document ID: 0
#   Relevance list: [False, False, False, False, False, False, False, False, False, True]
#   Precision@1: 0.0
#   Precision@5: 0.0
#   NDCG@5: 0.0
#
# Query 3:
#   Document ID: 0
#   Relevance list: [True, False, False, False, False, False, False, False, False, False]
#   Precision@1: 1.0
#   Precision@5: 0.2
#   NDCG@5: 1.0
#
# Query 4:
#   Document ID: 0
#   Relevance list: [True, False, False, False, False, False, False, False, False, False]
#   Precision@1: 1.0
#   Precision@5: 0.2
#   NDCG@5: 1.0
#
# Query 5:
#   Document ID: 1
#   Relevance list: [False, False, False, False, False, False, False, False, False, False]
#   Precision@1: 0.0
#   Precision@5: 0.0
#   NDCG@5: 0.0
#
# No results found for query ID: 54
# No results found for query ID: 164
# No results found for query ID: 191
# No results found for query ID: 200
# {'hit_rate': 0.8895348837209303, 'mrr': 0.5368620801033591, 'precision@1': np.float64(0.36046511627906974), 'precision@5': np.float64(0.15439276485788114), 'precision@10': np.float64(0.08917958656330749), 'map': np.float64(0.5368620801033591), 'ndcg@5': np.float64(0.5837805523380435), 'ndcg@10': np.float64(0.6222282111014733)}

# %%
df_validation=df_question[:100]
df_test=df_question[100:]

# %% [markdown]
# ## Finding Best Parameters

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
import random

def simple_optimize(param_ranges, objective_function, n_iterations=10):
    best_params = None
    best_score = float('-inf')  # Assuming we're minimizing. Use float('-inf') if maximizing.

    for _ in range(n_iterations):
        # Generate random parameters
        current_params = {}
        for param, (min_val, max_val) in param_ranges.items():
            if isinstance(min_val, int) and isinstance(max_val, int):
                current_params[param] = random.randint(min_val, max_val)
            else:
                current_params[param] = random.uniform(min_val, max_val)
        
        # Evaluate the objective function
        current_score = objective_function(current_params)
        
        # Update best if current is better
        if current_score > best_score:  # Change to > if maximizing
            best_score = current_score
            best_params = current_params
    
    return best_params, best_score

# %%
gt_val = df_validation.to_dict(orient='records')

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['question']))
# Out:
#   0%|          | 0/1036 [00:00<?, ?it/s]
# {'hit_rate': 0.8861003861003861, 'mrr': 0.5347892535392536}

# %%
def minsearch_search(query, boost=None):
    if boost is None:
        boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
documents[0]
# Out:
# {'id': 0,
#  'cell_nuclei_type': 'Epithelial',
#  'dataset_name': 'MoNuSAC',
#  'tasks': 'Segmentation',
#  'models': 'Hover-Net'}

# %%
param_ranges = {
    'cell_nuclei_type': (0.0, 3.0),
    'dataset_name': (0.0, 3.0),
    'tasks': (0.0, 3.0),
    'models': (0.0, 3.0),
}

def objective(boost_params):
    def search_function(q):
        return minsearch_search(q['question'], boost_params)

    results = evaluate(gt_val, search_function)
    return results['mrr']

# %%
simple_optimize(param_ranges, objective, n_iterations=20)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# ({'cell_nuclei_type': 1.6973335645050271,
#   'dataset_name': 0.9871311989222409,
#   'tasks': 1.3485356909349289,
#   'models': 2.759446425334579},
#  0.5368134920634922)

# %%
def minsearch_improved(query):
    boost = {
        'cell_nuclei_type': 1.69,
        'dataset_name': 0.98,
        'tasks': 1.34,
        'models': 2.75,
    }

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

evaluate(ground_truth, lambda q: minsearch_improved(q['question']))
# Out:
#   0%|          | 0/1036 [00:00<?, ?it/s]
# {'hit_rate': 0.8841698841698842, 'mrr': 0.5516550989765279}

# %%
prompt2_template = """
You are an expert evaluator for a RAG system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
len(ground_truth)
# Out:
# 1036

# %%
record = ground_truth[0]
question=record['question']
answer_llm=rag(question)
# Out:
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the segmentation tasks available for the Epithelial cell nuclei type?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net

# %%
print(answer_llm)
# Out:
# The segmentation tasks available for the Epithelial cell nuclei type include:
#
# 1. Segmentation in the LUNG dataset using the following models:
#    - DeepLabV3+
#    - ResNet
#    - UNet++
#    - FPN
#
# 2. Segmentation in the MoNuSAC dataset using:
#    - DenseUNet
#    - Hover-Net
#
# 3. Segmentation in the CoNSeP dataset using:
#    - HRNet
#    - DeepLab
#
# 4. Segmentation in the PanNuke dataset using:
#    - HRNet
#
# 5. Segmentation in the TNBC dataset using:
#    - ResNet

# %%
prompt = prompt2_template.format(question=question, answer_llm=answer_llm)
print(prompt)
# Out:
# You are an expert evaluator for a RAG system.
# Your task is to analyze the relevance of the generated answer to the given question.
# Based on the relevance of the generated answer, you will classify it
# as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Question: What are the segmentation tasks available for the Epithelial cell nuclei type?
# Generated Answer: The segmentation tasks available for the Epithelial cell nuclei type include:
#
# 1. Segmentation in the LUNG dataset using the following models:
#    - DeepLabV3+
#    - ResNet
#    - UNet++
#    - FPN
#
# 2. Segmentation in the MoNuSAC dataset using:
#    - DenseUNet
#    - Hover-Net
#
# 3. Segmentation in the CoNSeP dataset using:
#    - HRNet
#    - DeepLab
#
# 4. Segmentation in the PanNuke dataset using:
#    - HRNet
#
# 5. Segmentation in the TNBC dataset using:
#    - ResNet
#
# Please analyze the content and context of the generated answer in relation to the question
# and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }

# %%
llm(prompt)
# Out:
# '{\n  "Relevance": "RELEVANT",\n  "Explanation": "The generated answer lists specific segmentation tasks and models used for Epithelial cell nuclei across various datasets, directly addressing the question about available segmentation tasks for that cell type."\n}'

# %%
import json
df_sample = df_question.sample(n=200, random_state=1)
sample = df_sample.to_dict(orient='records')
evaluations = []

# %%
sample
# Out:
# [{'id': 213,
#   'question': 'What are the performance metrics of DenseUNet when applied to Plasma Cell segmentation in the CoNSeP dataset?'},
#  {'id': 144,
#   'question': 'Which tasks can the SSD model perform specifically for detecting epithelial cell nuclei?'},
#  {'id': 66,
#   'question': 'What are the advantages of using the Inception-V3 model for detecting cell nuclei types like plasma cells?'},
#  {'id': 248,
#   'question': 'What datasets are available for studying epithelial cell nuclei in the context of classification tasks?'},
#  {'id': 24,
#   'question': 'What features of the ResNet model make it effective for the task of segmenting macrophage cell nuclei?'},
#  {'id': 88,
#   'question': 'Can you provide details on how Inception-V3 performs in the detection of Plasma Cells within the LUNG dataset?'},
#  {'id': 201,
#   'question': 'Can you provide details on the segmentation tasks available for macrophage cell nuclei analysis?'},
#  {'id': 6,
#   'question': 'Are there any other models besides ResNet that are recommended for classifying macrophage cell nuclei in histopathological images?'},
#  {'id': 169,
#   'question': 'Can you provide information on tasks related to neutrophil detection using the Camelyon16 dataset?'},
#  {'id': 153,
#   'question': 'Can you provide information on the CoNSeP dataset specifically for Plasma Cell nuclei segmentation tasks?'},
#  {'id': 47,
#   'question': 'Can you provide information about the MoNuSAC dataset for macrophage nuclei classification tasks?'},
#  {'id': 189,
#   'question': 'What specific detection tasks can be performed on epithelial cell nuclei using the Camelyon17 dataset?'},
#  {'id': 185,
#   'question': 'Are there specific characteristics of macrophage nuclei that can be identified in the MoNuSAC dataset?'},
#  {'id': 237,
#   'question': 'What is the best model for segmenting plasma cells in histopathology images?'},
#  {'id': 217,
#   'question': 'Are there any other models besides DeepLabV3+ that are suitable for segmenting Macrophage nuclei?'},
#  {'id': 191,
#   'question': 'What specific tasks can be performed using the SSD model for neutrophil detection?'},
#  {'id': 8,
#   'question': 'Are there any additional datasets available for Plasma Cell detection beyond Camelyon16?'},
#  {'id': 157,
#   'question': 'Are there any specific challenges associated with segmenting macrophage nuclei in the context of the PanNuke dataset?'},
#  {'id': 87,
#   'question': 'Can you provide information on the PanNuke dataset and its relevance for neutrophil classification tasks?'},
#  {'id': 238,
#   'question': 'What specific tasks related to cell nuclei detection can be performed using SSD models on the Camelyon17 dataset?'},
#  {'id': 101,
#   'question': 'What is the best model for segmenting fibroblast cell nuclei in the TNBC dataset?'},
#  {'id': 85,
#   'question': 'What is the best model for detecting lymphocyte cell nuclei in histopathology images?'},
#  {'id': 38,
#   'question': 'How effective is the Hover-Net model for the task of detecting Plasma Cells in the PanNuke dataset?'},
#  {'id': 199,
#   'question': 'How does the performance of MobileNetV3 compare to other models when classifying Epithelial cell nuclei in histopathology?'},
#  {'id': 30,
#   'question': 'What are the characteristics of macrophage cell nuclei in the LUNG dataset?'},
#  {'id': 254,
#   'question': 'What is the best classification model available for analyzing epithelial cell nuclei in the PanNuke dataset?'},
#  {'id': 199,
#   'question': 'Can you provide examples of classification tasks that utilize the CoNSeP dataset for Epithelial cell nuclei?'},
#  {'id': 139,
#   'question': 'How does the performance of YOLOv4 compare to other models for lymphocyte detection in histopathology?'},
#  {'id': 47,
#   'question': 'Are there any recommended preprocessing steps for using the MoNuSAC dataset with the Mask R-CNN model for macrophage classification?'},
#  {'id': 114,
#   'question': 'Are there any alternative models to Faster R-CNN for the detection of Epithelial cell nuclei in the MoNuSAC dataset?'},
#  {'id': 1,
#   'question': 'What specific segmentation tasks can be performed using the Hover-Net model on lymphocyte nuclei?'},
#  {'id': 149,
#   'question': 'Which model is recommended for classifying fibroblast nuclei within the MoNuSAC dataset?'},
#  {'id': 195,
#   'question': 'What are the advantages of using the ResNet101 model for lymphocyte classification in histopathology studies?'},
#  {'id': 237,
#   'question': 'Can you provide details on the Camelyon16 dataset for plasma cell segmentation tasks?'},
#  {'id': 20,
#   'question': 'What are the characteristics of Plasma Cells as a cell nuclei type in the context of histopathology analysis?'},
#  {'id': 82,
#   'question': 'How effective is DeepLab in the segmentation of neutrophils compared to other models for the TNBC dataset?'},
#  {'id': 184,
#   'question': 'Can you provide detailed information about the Camelyon16 dataset specifically for the segmentation of lymphocyte nuclei?'},
#  {'id': 37,
#   'question': 'What are the best models available for segmenting and classifying neutrophil cell nuclei?'},
#  {'id': 254,
#   'question': 'What types of classification tasks can be performed using the Xception model for epithelial cell nuclei analysis?'},
#  {'id': 186,
#   'question': 'What specific detection tasks can be performed on neutrophil cell nuclei using the Faster R-CNN model?'},
#  {'id': 159,
#   'question': 'What are the characteristics of plasma cells that can be detected using the Camelyon16 dataset?'},
#  {'id': 194,
#   'question': 'What is the best model for detecting epithelial cell nuclei in the LUNG dataset?'},
#  {'id': 23,
#   'question': 'What are the strengths of using the U-Net model for lymphocyte detection in histopathology images?'},
#  {'id': 93,
#   'question': 'What classification tasks are typically conducted with neutrophil cell nuclei, and how does DenseNet perform in these tasks?'},
#  {'id': 12,
#   'question': 'Can you provide information on the segmentation tasks specifically related to macrophage nuclei in the TNBC dataset?'},
#  {'id': 226,
#   'question': 'What classification models are recommended for analyzing Neutrophil cell nuclei in histopathology?'},
#  {'id': 177,
#   'question': 'What are the primary challenges in classifying fibroblast nuclei using the NASNet model?'},
#  {'id': 255,
#   'question': 'What tasks can be performed with the SSD model when analyzing Lymphocyte cell nuclei?'},
#  {'id': 25,
#   'question': 'Which model is recommended for classifying neutrophil cell nuclei in histopathology images?'},
#  {'id': 45,
#   'question': 'What are the best models for detecting epithelial cell nuclei in the Camelyon16 dataset?'},
#  {'id': 65,
#   'question': 'Can you provide details about the PanNuke dataset that are particularly relevant for neutrophil cell nuclei segmentation?'},
#  {'id': 121,
#   'question': 'Are there any specific preprocessing steps recommended when using the PanNuke dataset for lymphocyte nuclei detection with YOLOv5?'},
#  {'id': 126,
#   'question': "What is the YOLOv4 model's performance for detecting epithelial cell nuclei in the TNBC dataset?"},
#  {'id': 48,
#   'question': 'What are the advantages of using the DeepLab model for segmentation of neutrophil cell nuclei?'},
#  {'id': 238,
#   'question': 'What is the best model, specifically SSD, for detecting macrophage cell nuclei in histopathological images?'},
#  {'id': 186,
#   'question': 'Which models are most effective for detecting neutrophil nuclei, specifically using Faster R-CNN?'},
#  {'id': 43,
#   'question': 'Are there any other models besides Inception-V3 that are effective for segmenting plasma cells in the MoNuSAC dataset?'},
#  {'id': 123,
#   'question': 'What specific features of neutrophil cell nuclei can the CoNSeP dataset help identify in classification tasks?'},
#  {'id': 29,
#   'question': 'Are there other datasets available for the classification of lymphocyte nuclei besides Camelyon16?'},
#  {'id': 228,
#   'question': 'What performance metrics should I consider when applying DenseUNet to fibroblast nuclei segmentation?'},
#  {'id': 50,
#   'question': 'Can you provide information on the PanNuke dataset specifically related to fibroblast nuclei detection?'},
#  {'id': 8,
#   'question': 'What specific tasks are associated with the Mask R-CNN model for analyzing Plasma Cells?'},
#  {'id': 10,
#   'question': 'Are there any specific challenges associated with classifying epithelial cell nuclei using the CoNSeP dataset?'},
#  {'id': 77,
#   'question': 'What specific classification tasks can be applied to Neutrophil cell nuclei using the LUNG dataset?'},
#  {'id': 68,
#   'question': 'Are there any other datasets besides MoNuSAC that are suitable for the detection of epithelial cell nuclei?'},
#  {'id': 184,
#   'question': 'What is the best model for segmenting lymphocyte nuclei in histopathology images?'},
#  {'id': 33,
#   'question': 'How effective is the Mask R-CNN model for the segmentation of fibroblast cell nuclei compared to other models?'},
#  {'id': 134,
#   'question': 'Which model is recommended for detecting macrophage cell nuclei in histopathology images from the MoNuSAC dataset?'},
#  {'id': 33,
#   'question': 'Are there any additional datasets available for fibroblast nuclei segmentation beyond MoNuSAC?'},
#  {'id': 21,
#   'question': 'Can you provide a detailed overview of the Camelyon16 dataset specifically for studying fibroblast cell nuclei?'},
#  {'id': 181,
#   'question': 'Are there any other models recommended alongside FPN for the segmentation of plasma cells in histopathology?'},
#  {'id': 91,
#   'question': 'Are there any specific characteristics of lymphocyte nuclei that can impact detection accuracy in the Camelyon17 dataset?'},
#  {'id': 107,
#   'question': 'What available datasets can be used for the detection of fibroblast cell nuclei?'},
#  {'id': 77,
#   'question': 'Which model is recommended for the classification task of Neutrophil cell nuclei in the LUNG dataset?'},
#  {'id': 167,
#   'question': 'How does the performance of YOLOv3 compare to other models for detecting epithelial cell nuclei in histopathology images?'},
#  {'id': 19,
#   'question': 'Which specific challenges are associated with the segmentation of neutrophil nuclei in the CoNSeP dataset?'},
#  {'id': 235,
#   'question': 'What is the best model for segmenting lymphocyte nuclei in the LUNG dataset?'},
#  {'id': 148,
#   'question': 'Can you provide details about the PanNuke dataset that is used for segmenting plasma cell nuclei?'},
#  {'id': 248,
#   'question': 'Are there any specific classification tasks available for epithelial cell nuclei in the TNBC dataset?'},
#  {'id': 124,
#   'question': 'What is the best model for detecting Plasma Cells in the LUNG dataset?'},
#  {'id': 216,
#   'question': 'How effective is YOLOv3 for the detection of lymphocyte cell nuclei compared to other models?'},
#  {'id': 27,
#   'question': 'What are the available datasets for detecting fibroblast cell nuclei?'},
#  {'id': 214,
#   'question': 'Which metrics are commonly used to evaluate the performance of models like YOLOv5 in the detection task for fibroblast nuclei?'},
#  {'id': 4,
#   'question': 'Can you provide information on the types of epithelial cell nuclei included in the PanNuke dataset?'},
#  {'id': 149,
#   'question': 'How does ResNet101 perform in the classification of fibroblast cell nuclei compared to other models?'},
#  {'id': 138,
#   'question': 'Can you provide details on the structure and types of epithelial cell nuclei represented in the LUNG dataset?'},
#  {'id': 200,
#   'question': 'Can you provide details on the tasks associated with detecting lymphocytes in histopathology datasets?'},
#  {'id': 246,
#   'question': 'What are the available datasets for detecting Plasma Cells aside from the LUNG dataset?'},
#  {'id': 85,
#   'question': 'Are there specific datasets available for lymphocyte detection tasks, particularly the CoNSeP dataset?'},
#  {'id': 16,
#   'question': 'Are there other datasets available for detection tasks involving epithelial cell nuclei aside from the LUNG dataset?'},
#  {'id': 59,
#   'question': 'What classification models are available for analyzing macrophage cell nuclei type in histopathology?'},
#  {'id': 64,
#   'question': 'What specific features of the Camelyon16 dataset make it suitable for macrophage segmentation tasks?'},
#  {'id': 26,
#   'question': 'What classification models, specifically ResNet, are suitable for analyzing plasma cell nuclei in the PanNuke dataset?'},
#  {'id': 76,
#   'question': 'What is the best model to use for segmenting macrophage nuclei in the PanNuke dataset?'},
#  {'id': 233,
#   'question': 'Are there any other datasets available for segmentation tasks related to Plasma Cells aside from MoNuSAC?'},
#  {'id': 253,
#   'question': 'Are there other datasets besides Camelyon16 that are suitable for fibroblast detection in histopathology analysis?'},
#  {'id': 45,
#   'question': 'Can you provide details on the types of tasks involved in using the Camelyon16 dataset for epithelial cell nuclei detection?'},
#  {'id': 230,
#   'question': 'What is the best model for classifying lymphocyte cell nuclei types in histopathology analysis?'},
#  {'id': 48,
#   'question': 'Are there alternative datasets for neutrophil segmentation tasks in histopathology studies besides TNBC?'},
#  {'id': 175,
#   'question': 'What types of tasks can be performed using YOLOv4 for cell nuclei analysis, particularly involving neutrophils?'},
#  {'id': 238,
#   'question': 'Are there any other datasets besides Camelyon17 that are suited for detecting macrophage nuclei in histopathology?'},
#  {'id': 224,
#   'question': 'Which models, specifically SSD, are suitable for detecting lymphocyte cell nuclei?'},
#  {'id': 202,
#   'question': 'What tasks related to Neutrophil cell nuclei can be performed using the EfficientNet-B2 model?'},
#  {'id': 60,
#   'question': 'Can you provide details about the MoNuSAC dataset used for neutrophil segmentation?'},
#  {'id': 22,
#   'question': 'Are there any specific strategies for optimizing Inception-V3 when applied to the classification of Epithelial cell nuclei?'},
#  {'id': 75,
#   'question': 'Can you provide information on the TNBC dataset and its relevance for detecting lymphocyte nuclei?'},
#  {'id': 82,
#   'question': 'Can you provide details on the availability of the TNBC dataset for tasks involving neutrophil segmentation?'},
#  {'id': 55,
#   'question': 'What are the key challenges in segmenting plasma cells using the PanNuke dataset?'},
#  {'id': 159,
#   'question': 'Are there any alternative models to YOLOv5 that can also detect plasma cells in histopathological datasets like Camelyon16?'},
#  {'id': 157,
#   'question': 'Can you provide details about the PanNuke dataset and its relevance for studying macrophage segmentation?'},
#  {'id': 249,
#   'question': 'What is the best model available for segmenting lymphocyte cell nuclei in the MoNuSAC dataset?'},
#  {'id': 50,
#   'question': 'What are the advantages of using U-Net for detecting fibroblast nuclei in histopathology images?'},
#  {'id': 165,
#   'question': 'Are there any specific challenges in using the MoNuSAC dataset for plasma cell classification tasks?'},
#  {'id': 147,
#   'question': 'Are there any specific preprocessing steps recommended for using the Camelyon17 dataset with YOLOv5 for detection tasks?'},
#  {'id': 57,
#   'question': 'What are the advantages of using ResNet for the detection of epithelial cell nuclei in the CoNSeP dataset?'},
#  {'id': 168,
#   'question': 'How does RetinaNet perform when applied to the segmentation of macrophage cell nuclei in histopathology images?'},
#  {'id': 60,
#   'question': 'What is the performance of the DeepLab model in detecting and segmenting neutrophil nuclei?'},
#  {'id': 174,
#   'question': 'Which models are recommended for classifying macrophage nuclei in histopathology, specifically using EfficientNet-B0?'},
#  {'id': 14,
#   'question': 'Are there any specific challenges in segmenting plasma cells using ResNet, and how can they be addressed?'},
#  {'id': 3,
#   'question': 'Can you provide insights on the performance of the Hover-Net model for segmenting Neutrophil cell nuclei?'},
#  {'id': 39,
#   'question': 'What is the best model for segmenting fibroblast nuclei in the TNBC dataset?'},
#  {'id': 100,
#   'question': 'How effective is the Xception model in classifying images derived from the PanNuke dataset for Plasma Cells?'},
#  {'id': 183,
#   'question': 'Can you provide details on the performance of RetinaNet when applied to the TNBC dataset for epithelial nuclei detection?'},
#  {'id': 214,
#   'question': 'What are the specific detection capabilities of YOLOv5 for identifying fibroblast cell nuclei in histopathology images?'},
#  {'id': 122,
#   'question': 'Are there any additional datasets available for segmentation tasks focusing on macrophage nuclei besides Camelyon17?'},
#  {'id': 144,
#   'question': 'What are the characteristics of epithelial cell nuclei in the MoNuSAC dataset?'},
#  {'id': 218,
#   'question': 'Are there any additional datasets apart from CoNSeP available for Neutrophil nuclei classification tasks?'},
#  {'id': 183,
#   'question': 'Are there any specific tasks associated with epithelial cell nuclei analysis besides detection?'},
#  {'id': 121,
#   'question': 'What is the performance of YOLOv5 in detecting lymphocyte cell nuclei compared to other models?'},
#  {'id': 132,
#   'question': 'Can you provide details about the CoNSeP dataset and its applicability to segmentation tasks for epithelial cell nuclei?'},
#  {'id': 86,
#   'question': 'Which model, specifically Mask R-CNN, is most effective for segmentation tasks involving macrophage nuclei?'},
#  {'id': 227,
#   'question': "Can you provide information on the YOLOv4 model's performance for detecting Plasma Cells?"},
#  {'id': 220,
#   'question': 'Can you provide details about the Camelyon16 dataset used for classifying epithelial cell nuclei?'},
#  {'id': 91,
#   'question': 'What is the best model available for detecting lymphocyte nuclei in the Camelyon17 dataset?'},
#  {'id': 76,
#   'question': 'Are there specific parameters recommended for using Mask R-CNN on macrophage nuclei in the PanNuke dataset?'},
#  {'id': 88,
#   'question': 'What tasks are typically associated with the analysis of Plasma Cells in histopathology, and how can they be applied to the LUNG dataset?'},
#  {'id': 0,
#   'question': 'What are the performance metrics for the Hover-Net model when applied to the MoNuSAC dataset for Epithelial nuclei segmentation?'},
#  {'id': 226,
#   'question': 'Which tasks are most suitable for datasets that include Neutrophil cell nuclei, and how does the MoNuSAC dataset fit into this?'},
#  {'id': 195,
#   'question': 'Can you provide an overview of the classification task associated with lymphocyte cell nuclei analysis using the PanNuke dataset?'},
#  {'id': 86,
#   'question': 'What datasets are available for studying macrophage nuclei segmentation beyond MoNuSAC?'},
#  {'id': 244,
#   'question': 'Are there any additional datasets available for the detection of lymphocyte cell nuclei besides MoNuSAC?'},
#  {'id': 252,
#   'question': 'Can you provide details on how DeepLabV3+ performs in segmenting plasma cell nuclei?'},
#  {'id': 46,
#   'question': 'What specific characteristics of lymphocyte cell nuclei are captured in the LUNG dataset for segmentation and classification purposes?'},
#  {'id': 51,
#   'question': 'Are there any other datasets besides LUNG that are appropriate for segmentation tasks involving epithelial cell nuclei?'},
#  {'id': 120,
#   'question': 'Which model, specifically MobileNet, is most effective for classifying Epithelial cell nuclei?'},
#  {'id': 63,
#   'question': 'How does the classification accuracy of Hover-Net compare to other models specifically for Lymphocyte cell nuclei in histopathology analysis?'},
#  {'id': 50,
#   'question': 'What are the characteristics of the fibroblast cell nuclei that make them suitable for detection tasks?'},
#  {'id': 0,
#   'question': 'Which specific model, such as Hover-Net, is best suited for segmenting Epithelial cell nuclei in histopathology?'},
#  {'id': 102,
#   'question': 'What are the capabilities of the MoNuSAC dataset for detecting epithelial cell nuclei?'},
#  {'id': 18,
#   'question': 'What classification models are best suited for analyzing macrophage cell nuclei in the TNBC dataset?'},
#  {'id': 235,
#   'question': 'Is the FPN model suitable for lymphocyte cell nucleus segmentation, and what are its advantages?'},
#  {'id': 35,
#   'question': 'Can you provide examples of datasets available for the detection of lymphocyte nuclei, particularly in the context of lung pathology?'},
#  {'id': 138,
#   'question': 'How does the FPN model perform in segmenting epithelial cell nuclei compared to other available models for the LUNG dataset?'},
#  {'id': 179,
#   'question': 'Can you provide details about the CoNSeP dataset and its relevance for lymphocyte segmentation tasks?'},
#  {'id': 217,
#   'question': 'What is the effectiveness of the DeepLabV3+ model when applied to Macrophage nuclei segmentation tasks?'},
#  {'id': 41,
#   'question': 'Can you provide details on the LUNG dataset specifically related to macrophage detection tasks?'},
#  {'id': 214,
#   'question': 'Are there any other models besides YOLOv5 that are suitable for detecting fibroblast cell nuclei in the Camelyon17 dataset?'},
#  {'id': 202,
#   'question': 'What is the best classification model for analyzing Neutrophil cell nuclei in histopathology images?'},
#  {'id': 18,
#   'question': 'Can you provide a list of datasets specifically available for classifying macrophage cell nuclei?'},
#  {'id': 29,
#   'question': 'Can you provide details on the Camelyon16 dataset specifically for the classification of lymphocyte nuclei?'},
#  {'id': 211,
#   'question': 'What are the best models for detecting macrophage cell nuclei in the Camelyon16 dataset?'},
#  {'id': 84,
#   'question': 'What specific tasks are involved in the classification of epithelial cells within the TNBC dataset?'},
#  {'id': 27,
#   'question': 'How effective is Mask R-CNN in detecting fibroblast nuclei within the TNBC dataset?'},
#  {'id': 1,
#   'question': 'Can you provide information about the MoNuSAC dataset for lymphocyte segmentation tasks?'},
#  {'id': 132,
#   'question': 'Are there any other models besides DenseNet that are recommended for segmentation of epithelial cell nuclei?'},
#  {'id': 70,
#   'question': 'Can you recommend any specific models, apart from Mask R-CNN, for the classification of macrophage nuclei?'},
#  {'id': 110,
#   'question': 'What other datasets might complement the PanNuke dataset for studying macrophage nuclei in histopathology?'},
#  {'id': 187,
#   'question': 'What are the specific features of Plasma Cells in the PanNuke dataset?'},
#  {'id': 109,
#   'question': 'Can you provide details on the classification tasks associated with Lymphocyte cell nuclei?'},
#  {'id': 147,
#   'question': 'What types of detection tasks are most commonly performed on Neutrophil cell nuclei using the Camelyon17 dataset?'},
#  {'id': 149,
#   'question': 'What specific characteristics of the MoNuSAC dataset make it suitable for fibroblast nuclei classification tasks?'},
#  {'id': 2,
#   'question': 'What datasets are available for the segmentation of macrophage cell nuclei?'},
#  {'id': 103,
#   'question': 'What specific classification tasks can be performed using the Camelyon17 dataset for lymphocyte cell nuclei?'},
#  {'id': 14,
#   'question': 'What datasets are available for segmentation tasks involving plasma cell nuclei?'},
#  {'id': 108,
#   'question': 'Which specific segmentation models are best suited for analyzing Epithelial cell nuclei, specifically DenseUNet?'},
#  {'id': 210,
#   'question': 'What are the specific characteristics of lymphocyte nuclei that are important for segmentation tasks?'},
#  {'id': 209,
#   'question': 'How effective is the YOLOv4 model in detecting Epithelial cell nuclei compared to other models in the LUNG dataset?'},
#  {'id': 245,
#   'question': 'What are the characteristics of Neutrophil cell nuclei as identified in the Camelyon16 dataset?'},
#  {'id': 21,
#   'question': 'What are the segmentation capabilities of the DeepLab model when applied to fibroblast cell nuclei in the Camelyon16 dataset?'},
#  {'id': 257,
#   'question': 'Are there any specific tasks available for analyzing Neutrophil nuclei, aside from classification?'},
#  {'id': 39,
#   'question': 'What datasets are available for segmenting fibroblast cell types, specifically in the context of TNBC?'},
#  {'id': 113,
#   'question': 'What is the best model for classifying fibroblast cell nuclei in the Camelyon17 dataset?'},
#  {'id': 31,
#   'question': 'Can you provide details on the segmentation task specifically for neutrophils using the ResNet model?'},
#  {'id': 192,
#   'question': "What is the HRNet model's performance like for segmenting plasma cell nuclei in the CoNSeP dataset?"},
#  {'id': 232,
#   'question': 'Which models, including RetinaNet, are most effective for detecting neutrophil nuclei in histopathology images?'},
#  {'id': 212,
#   'question': 'Are there alternative models available for classifying neutrophil cell nuclei aside from Inception-V3?'},
#  {'id': 236,
#   'question': 'Which performance metrics can be expected when using YOLOv5 for neutrophil detection tasks?'},
#  {'id': 204,
#   'question': 'Can you provide details about the PanNuke dataset specifically tailored for fibroblast cell nuclei segmentation tasks?'},
#  {'id': 207,
#   'question': 'How does the Faster R-CNN model perform specifically for the detection of Neutrophil nuclei in the context of the Camelyon17 dataset?'},
#  {'id': 203,
#   'question': 'How does YOLOv5 perform in detecting plasma cells compared to other models?'},
#  {'id': 144,
#   'question': 'How does the performance of the SSD model compare to other models when detecting epithelial cell nuclei in the MoNuSAC dataset?'},
#  {'id': 153,
#   'question': 'What are the advantages of using DenseNet for segmentation tasks involving Plasma Cells?'},
#  {'id': 160,
#   'question': 'What specific segmentation task can be performed using the PanNuke dataset for fibroblast cell nuclei?'},
#  {'id': 20,
#   'question': 'Which datasets, specifically the PanNuke dataset, are best suited for the detection tasks involving Plasma Cells?'},
#  {'id': 140,
#   'question': 'What classification tasks are available for analyzing Macrophage cell nuclei?'},
#  {'id': 103,
#   'question': 'Are there alternative datasets to Camelyon17 that include lymphocyte nuclei for classification tasks?'},
#  {'id': 118,
#   'question': "Can you provide details on the Attn-UNet model's performance when applied to plasma cell segmentation?"},
#  {'id': 154,
#   'question': 'How does the detection of fibroblast nuclei using YOLOv3 compare to other models?'},
#  {'id': 95,
#   'question': 'What is the performance of UNet++ when applied to segmentation tasks for fibroblast nuclei in histopathology analysis?'},
#  {'id': 187,
#   'question': 'How can I utilize UNet++ for segmentation tasks involving Plasma Cells?'}]

# %%
for record in tqdm(sample):
    question = record['question']
    answer_llm = rag(question) 

    prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )

    evaluation = llm(prompt)
    evaluation = json.loads(evaluation)

    evaluations.append((record, answer_llm, evaluation))
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the performance metrics of DenseUNet when applied to Plasma Cell segmentation in the CoNSeP dataset?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Macrophage
# dataset_name: CoNSeP
# tasks: Segmentation
# models: RetinaNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Segmentation
# models: UNet++
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Which tasks can the SSD model perform specifically for detecting epithelial cell nuclei?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the advantages of using the Inception-V3 model for detecting cell nuclei types like plasma cells?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What datasets are available for studying epithelial cell nuclei in the context of classification tasks?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon17
# tasks: Classification
# models: ResNet101
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Classification
# models: MobileNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Classification
# models: Inception-V4
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What features of the ResNet model make it effective for the task of segmenting macrophage cell nuclei?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon16
# tasks: Detection
# models: ResNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide details on how Inception-V3 performs in the detection of Plasma Cells within the LUNG dataset?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: Faster R-CNN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide details on the segmentation tasks available for macrophage cell nuclei analysis?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: CoNSeP
# tasks: Segmentation
# models: RetinaNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there any other models besides ResNet that are recommended for classifying macrophage cell nuclei in histopathological images?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon16
# tasks: Detection
# models: ResNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide information on tasks related to neutrophil detection using the Camelyon16 dataset?
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Classification
# models: DeepLab
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: YOLOv3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide information on the CoNSeP dataset specifically for Plasma Cell nuclei segmentation tasks?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: EfficientNet-B3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Segmentation
# models: PSPNet
#
# cell_nuclei_type: Macrophage
# dataset_name: CoNSeP
# tasks: Segmentation
# models: RetinaNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide information about the MoNuSAC dataset for macrophage nuclei classification tasks?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Classification
# models: UNet++
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Classification
# models: MobileNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Classification
# models: EfficientNet
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNet101
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What specific detection tasks can be performed on epithelial cell nuclei using the Camelyon17 dataset?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there specific characteristics of macrophage nuclei that can be identified in the MoNuSAC dataset?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet3+
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What is the best model for segmenting plasma cells in histopathology images?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there any other models besides DeepLabV3+ that are suitable for segmenting Macrophage nuclei?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Macrophage
# dataset_name: CoNSeP
# tasks: Segmentation
# models: RetinaNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: Mask R-CNN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What specific tasks can be performed using the SSD model for neutrophil detection?
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: Faster R-CNN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there any additional datasets available for Plasma Cell detection beyond Camelyon16?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Mask R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there any specific challenges associated with segmenting macrophage nuclei in the context of the PanNuke dataset?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: EfficientNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: ResNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide information on the PanNuke dataset and its relevance for neutrophil classification tasks?
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation and Classification
# models: DeepLab
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-ResNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: DeepLab
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What specific tasks related to cell nuclei detection can be performed using SSD models on the Camelyon17 dataset?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: CoNSeP
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon17
# tasks: Detection
# models: EfficientNet
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What is the best model for segmenting fibroblast cell nuclei in the TNBC dataset?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Detection
# models: Mask R-CNN
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: LinkNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What is the best model for detecting lymphocyte cell nuclei in histopathology images?
#
# CONTEXT:
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet3+
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Classification
# models: DenseNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Detection
# models: RetinaNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How effective is the Hover-Net model for the task of detecting Plasma Cells in the PanNuke dataset?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How does the performance of MobileNetV3 compare to other models when classifying Epithelial cell nuclei in histopathology?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Macrophage
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon16
# tasks: Classification
# models: DenseNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: ResNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the characteristics of macrophage cell nuclei in the LUNG dataset?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Detection
# models: Hover-Net
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: DenseNet
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Detection
# models: U-Net
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: Inception-V3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What is the best classification model available for analyzing epithelial cell nuclei in the PanNuke dataset?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-ResNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: DeepLab
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Classification
# models: Inception-V4
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Lymphocyte
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet101
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide examples of classification tasks that utilize the CoNSeP dataset for Epithelial cell nuclei?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: ResNet50
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: EfficientNet-B3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: ResNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How does the performance of YOLOv4 compare to other models for lymphocyte detection in histopathology?
#
# CONTEXT:
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Lymphocyte
# dataset_name: CoNSeP
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Detection
# models: U-Net
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv4
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there any recommended preprocessing steps for using the MoNuSAC dataset with the Mask R-CNN model for macrophage classification?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Segmentation and Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Classification
# models: MobileNet
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: Mask R-CNN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there any alternative models to Faster R-CNN for the detection of Epithelial cell nuclei in the MoNuSAC dataset?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What specific segmentation tasks can be performed using the Hover-Net model on lymphocyte nuclei?
#
# CONTEXT:
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: CoNSeP
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: CoNSeP
# tasks: Detection
# models: Hover-Net
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Classification
# models: Hover-Net
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Which model is recommended for classifying fibroblast nuclei within the MoNuSAC dataset?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Detection
# models: U-Net
#
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNet101
#
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Classification
# models: EfficientNet-B0
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the advantages of using the ResNet101 model for lymphocyte classification in histopathology studies?
#
# CONTEXT:
# cell_nuclei_type: Lymphocyte
# dataset_name: PanNuke
# tasks: Classification
# models: ResNet101
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: PanNuke
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNet50
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon17
# tasks: Classification
# models: MobileNetV2
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Classification
# models: Inception-V4
#
# cell_nuclei_type: Lymphocyte
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V4
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Classification
# models: Inception-V3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide details on the Camelyon16 dataset for plasma cell segmentation tasks?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Segmentation
# models: Mask R-CNN
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the characteristics of Plasma Cells as a cell nuclei type in the context of histopathology analysis?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How effective is DeepLab in the segmentation of neutrophils compared to other models for the TNBC dataset?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Segmentation and Classification
# models: DeepLab
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Segmentation
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DeepLab
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Segmentation
# models: PSPNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide detailed information about the Camelyon16 dataset specifically for the segmentation of lymphocyte nuclei?
#
# CONTEXT:
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation
# models: EfficientNet-B1
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Lymphocyte
# dataset_name: CoNSeP
# tasks: Segmentation
# models: UNet3+
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: EfficientNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: PSPNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the best models available for segmenting and classifying neutrophil cell nuclei?
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Segmentation and Classification
# models: DeepLab
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation and Classification
# models: DeepLab
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: ResNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation and Classification
# models: Hover-Net
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation and Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Segmentation and Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Segmentation and Classification
# models: Hover-Net
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What types of classification tasks can be performed using the Xception model for epithelial cell nuclei analysis?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Lymphocyte
# dataset_name: PanNuke
# tasks: Classification
# models: Xception
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Classification
# models: Inception-V4
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Classification
# models: Inception-V3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What specific detection tasks can be performed on neutrophil cell nuclei using the Faster R-CNN model?
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: Mask R-CNN
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: Faster R-CNN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the characteristics of plasma cells that can be detected using the Camelyon16 dataset?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Segmentation
# ...
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: YOLOv3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide details about the PanNuke dataset specifically tailored for fibroblast cell nuclei segmentation tasks?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: FPN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How does the Faster R-CNN model perform specifically for the detection of Neutrophil nuclei in the context of the Camelyon17 dataset?
#
# CONTEXT:
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon16
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: RetinaNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: Mask R-CNN
#
# cell_nuclei_type: Neutrophil
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How does YOLOv5 perform in detecting plasma cells compared to other models?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon17
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How does the performance of the SSD model compare to other models when detecting epithelial cell nuclei in the MoNuSAC dataset?
#
# CONTEXT:
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Neutrophil
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Classification
# models: Inception-V3
#
# cell_nuclei_type: Epithelial
# dataset_name: TNBC
# tasks: Detection
# models: SSD
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Detection
# models: ResNet
#
# cell_nuclei_type: Epithelial
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: Hover-Net
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What are the advantages of using DenseNet for segmentation tasks involving Plasma Cells?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Epithelial
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon17
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: Inception-V3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What specific segmentation task can be performed using the PanNuke dataset for fibroblast cell nuclei?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: FPN
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Which datasets, specifically the PanNuke dataset, are best suited for the detection tasks involving Plasma Cells?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: Inception-V3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: Mask R-CNN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: Hover-Net
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv4
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Detection
# models: U-Net
#
# cell_nuclei_type: Epithelial
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What classification tasks are available for analyzing Macrophage cell nuclei?
#
# CONTEXT:
# cell_nuclei_type: Macrophage
# dataset_name: Camelyon16
# tasks: Classification
# models: MobileNetV3
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: ResNet
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: EfficientNet
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Macrophage
# dataset_name: CoNSeP
# tasks: Classification
# models: EfficientNet-B2
#
# cell_nuclei_type: Macrophage
# dataset_name: LUNG
# tasks: Classification
# models: DenseNet
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Classification
# models: Mask R-CNN
#
# cell_nuclei_type: Macrophage
# dataset_name: TNBC
# tasks: Classification
# models: EfficientNet-B0
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Are there alternative datasets to Camelyon17 that include lymphocyte nuclei for classification tasks?
#
# CONTEXT:
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon17
# tasks: Classification
# models: MobileNetV2
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Classification
# models: NASNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon17
# tasks: Classification
# models: ResNeXt
#
# cell_nuclei_type: Plasma Cell
# dataset_name: Camelyon17
# tasks: Classification
# models: MobileNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Classification
# models: ResNet50
#
# cell_nuclei_type: Epithelial
# dataset_name: Camelyon17
# tasks: Classification
# models: ResNet101
#
# cell_nuclei_type: Lymphocyte
# dataset_name: Camelyon16
# tasks: Classification
# models: DenseNet
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Classification
# models: Hover-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Classification
# models: NASNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: Can you provide details on the Attn-UNet model's performance when applied to plasma cell segmentation?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Plasma Cell
# dataset_name: LUNG
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: FPN
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DenseNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: DenseUNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Plasma Cell
# dataset_name: CoNSeP
# tasks: Segmentation
# models: DenseNet
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How does the detection of fibroblast nuclei using YOLOv3 compare to other models?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Neutrophil
# dataset_name: TNBC
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Neutrophil
# dataset_name: LUNG
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Detection
# models: YOLOv5
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Detection
# models: Faster R-CNN
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Detection
# models: U-Net
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Detection
# models: YOLOv3
#
# cell_nuclei_type: Lymphocyte
# dataset_name: TNBC
# tasks: Detection
# models: YOLOv3
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: What is the performance of UNet++ when applied to segmentation tasks for fibroblast nuclei in histopathology analysis?
#
# CONTEXT:
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon17
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: DeepLabV3+
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: LinkNet
#
# cell_nuclei_type: Fibroblast
# dataset_name: TNBC
# tasks: Segmentation
# models: U-Net
#
# cell_nuclei_type: Fibroblast
# dataset_name: Camelyon16
# tasks: Segmentation
# models: HRNet
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
# You are a histopathology expert. Answer the QUESTION based on the CONTEXT from our cell nuclei dataset.
# Use only the facts from the CONTEXT when answering the QUESTION.
#
# QUESTION: How can I utilize UNet++ for segmentation tasks involving Plasma Cells?
#
# CONTEXT:
# cell_nuclei_type: Plasma Cell
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Plasma Cell
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Plasma Cell
# dataset_name: TNBC
# tasks: Segmentation
# models: Attn-UNet
#
# cell_nuclei_type: Macrophage
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Neutrophil
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Lymphocyte
# dataset_name: MoNuSAC
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Fibroblast
# dataset_name: CoNSeP
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Epithelial
# dataset_name: LUNG
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Lymphocyte
# dataset_name: LUNG
# tasks: Segmentation
# models: UNet++
#
# cell_nuclei_type: Macrophage
# dataset_name: PanNuke
# tasks: Segmentation
# models: UNet++

# %%
df_eval = pd.DataFrame(evaluations, columns=['record', 'answer', 'evaluation'])

df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
df_eval['question'] = df_eval.record.apply(lambda d: d['question'])

df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])

del df_eval['record']
del df_eval['evaluation']

# %%
df_eval.relevance.value_counts()
# Out:
# relevance
# RELEVANT           117
# PARTLY_RELEVANT     68
# NON_RELEVANT        15
# Name: count, dtype: int64

# %%
df_eval.to_csv('data/rag-eval-gpt-4o-mini.csv', index=False)

# %%
df_eval[df_eval.relevance == 'NON_RELEVANT']
# Out:
#                                                 answer   id  \
# 7    Based on the provided context, ResNet is the o...    6
# 28   The provided context does not include specific...   47
# 62   The provided context does not explicitly menti...   10
# 75   The context does not explicitly outline the sp...   19
# 86   I'm sorry, but it appears that the CONTEXT you...  200
# 87   The available datasets for detecting Plasma Ce...  246
# 89   Based on the provided context, the only datase...   16
# 100  Based on the provided context, Camelyon17 is t...  238
# 104  The provided CONTEXT does not specify any stra...   22
# 113  The CONTEXT provided does not specify any part...  147
# 118  The provided context does not explicitly menti...   14
# 125  The characteristics of epithelial cell nuclei ...  144
# 143  Based on the provided context, the only datase...   51
# 145  The context does not provide specific classifi...   63
# 189  The context does not provide a comparison of Y...  203
#
#                                               question     relevance  \
# 7    Are there any other models besides ResNet that...  NON_RELEVANT
# 28   Are there any recommended preprocessing steps ...  NON_RELEVANT
# 62   Are there any specific challenges associated w...  NON_RELEVANT
# 75   Which specific challenges are associated with ...  NON_RELEVANT
# 86   Can you provide details on the tasks associate...  NON_RELEVANT
# 87   What are the available datasets for detecting ...  NON_RELEVANT
# 89   Are there other datasets available for detecti...  NON_RELEVANT
# 100  Are there any other datasets besides Camelyon1...  NON_RELEVANT
# 104  Are there any specific strategies for optimizi...  NON_RELEVANT
# 113  Are there any specific preprocessing steps rec...  NON_RELEVANT
# 118  Are there any specific challenges in segmentin...  NON_RELEVANT
# 125  What are the characteristics of epithelial cel...  NON_RELEVANT
# 143  Are there any other datasets besides LUNG that...  NON_RELEVANT
# 145  How does the classification accuracy of Hover-...  NON_RELEVANT
# 189  How does YOLOv5 perform in detecting plasma ce...  NON_RELEVANT
#
#                                            explanation
# 7    The generated answer states that ResNet is the...
# 28   The generated answer does not address the ques...
# 62   The generated answer does not address the ques...
# 75   The generated answer states that it cannot pro...
# 86   The generated answer does not provide any info...
# 87   The generated answer does not provide any alte...
# 89   The generated answer does not provide any addi...
# 100  The generated answer explicitly states that Ca...
# 104  The generated answer does not provide any stra...
# 113  The generated answer does not provide any rele...
# 118  The generated answer does not address the ques...
# 125  The generated answer does not provide any char...
# 143  The generated answer does not provide any alte...
# 145  The generated answer acknowledges the lack of ...
# 189  The generated answer explicitly states that it...

# %%
evaluations_gpt4o = []

for record in tqdm(sample):
    question = record['question']
    answer_llm = rag(question, model='gpt-4o') 

    prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )

    evaluation = llm(prompt)
    evaluation = json.loads(evaluation)
    
    evaluations_gpt4o.append((record, answer_llm, evaluation))
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
df_eval = pd.DataFrame(evaluations_gpt4o, columns=['record', 'answer', 'evaluation'])

df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
df_eval['question'] = df_eval.record.apply(lambda d: d['question'])

df_eval['relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
df_eval['explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])

del df_eval['record']
del df_eval['evaluation']
df_eval.relevance.value_counts()
# Out:
# relevance
# RELEVANT           115
# PARTLY_RELEVANT     72
# NON_RELEVANT        13
# Name: count, dtype: int64

# %%
df_eval.relevance.value_counts(normalize=True)
# Out:
# relevance
# RELEVANT           0.575
# PARTLY_RELEVANT    0.360
# NON_RELEVANT       0.065
# Name: proportion, dtype: float64

# %%
df_eval.to_csv('data/rag-eval-gpt-4o.csv', index=False)
